# %%
# %load_ext autoreload
# %autoreload 2
# %aimport resultParser

import pickle as pk

import scanpy as sc
from scipy.sparse import csr_matrix
import pandas as pd

from resultParser import ResultParser

# %%
combined_data = ResultParser.load_results("temp/outputs_2", combine=True)

# %%
frqc_mat = ResultParser.frequency_matrix(loaded_dict=combined_data)

# %%
frqc_mat.head()
# Out:
#                                           OTX1  RREB1  DMRT2  COMP1  AP1  \
# chr1_11869_+_ENSG00000223972_DDX11L1         4      0      0      0   10
# chr1_12010_+_ENSG00000223972_DDX11L1         4      0      0      0    7
# chr1_29570_-_ENSG00000227232_WASH7P          4      0      0      0    9
# chr1_17436_-_ENSG00000278267_MIR6859-1       0      0      0      0    8
# chr1_29554_+_ENSG00000243485_MIR1302-2HG     0      0      0      0   15
#
#                                           NOTO  HOXD1  TBX2  TBX20  IKZF1  \
# chr1_11869_+_ENSG00000223972_DDX11L1         1      0     0      0      0
# chr1_12010_+_ENSG00000223972_DDX11L1         1      0     0      0      0
# chr1_29570_-_ENSG00000227232_WASH7P          0      0     0      0      1
# chr1_17436_-_ENSG00000278267_MIR6859-1       0      0     0      0      0
# chr1_29554_+_ENSG00000243485_MIR1302-2HG     0      0     0      0      0
#
#                                           ...  DLX4  GBX2  LMX1A  RARB  EGR4  \
# chr1_11869_+_ENSG00000223972_DDX11L1      ...     1     1      0     0     0
# chr1_12010_+_ENSG00000223972_DDX11L1      ...     1     1      0     0     0
# chr1_29570_-_ENSG00000227232_WASH7P       ...     1     0      0     0     0
# chr1_17436_-_ENSG00000278267_MIR6859-1    ...     0     0      0     0     0
# chr1_29554_+_ENSG00000243485_MIR1302-2HG  ...     0     0      0     0     0
#
#                                           ZSCAN26  NFE2L1::MAFG  HNF4  EVX1  \
# chr1_11869_+_ENSG00000223972_DDX11L1            0             1    25     1
# chr1_12010_+_ENSG00000223972_DDX11L1            0             1    28     1
# chr1_29570_-_ENSG00000227232_WASH7P             0             0    39     0
# chr1_17436_-_ENSG00000278267_MIR6859-1          0             0    48     1
# chr1_29554_+_ENSG00000243485_MIR1302-2HG        0             0    16     0
#
#                                           SMAD4
# chr1_11869_+_ENSG00000223972_DDX11L1          0
# chr1_12010_+_ENSG00000223972_DDX11L1          0
# chr1_29570_-_ENSG00000227232_WASH7P           0
# chr1_17436_-_ENSG00000278267_MIR6859-1        0
# chr1_29554_+_ENSG00000243485_MIR1302-2HG      0
#
# [5 rows x 616 columns]

# %%
ad = sc.AnnData(frqc_mat)
ad.X = csr_matrix(ad.X)
ad.obs['chr'] = [i.split('_')[0] for i in ad.obs.index]
ad.obs['gene_id'] = [i.split('_')[3] for i in ad.obs.index]
ad.obs['gene_name'] = [i.split('_')[4] for i in ad.obs.index]

# %%
ad.write('outputs/motif_frequencies.h5ad')
# Out:
# ... storing 'chr' as categorical
# ... storing 'gene_id' as categorical
# ... storing 'gene_name' as categorical
